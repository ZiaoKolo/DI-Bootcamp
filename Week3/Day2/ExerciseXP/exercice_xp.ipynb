# %% [markdown]
# ## Exercice 1

# %%
import numpy as np

#Matrice 3x3
matrice = np.array([[1, 2, 3], [0, 1, 4], [5, 6, 0]])
determinant = np.linalg.det(matrice)
print("Déterminant de la matrice : ", determinant)
inverse = np.linalg.inv(matrice)
print("Inverse de la matrice : \n", inverse)
# Out:
# Déterminant de la matrice :  0.9999999999999964
# Inverse de la matrice :
#  [[-24.  18.   5.]
#  [ 20. -15.  -4.]
#  [ -5.   4.   1.]]

# %% [markdown]
# ## Exercice 2

# %%
tab = np.random.rand(50)

moyenne = np.mean(tab)
ecart_type = np.std(tab)

print("Moyenne : ", moyenne)
print("Ecart type : ", ecart_type)
# Out:
# Moyenne :  0.4404348304845488
# Ecart type :  0.26984794912181215

# %% [markdown]
# ## Exercice 3

# %%
import numpy as np

# Dates du 1er au 31 janvier 2023
dates = np.arange('2023-01-01', '2023-02-01', dtype='datetime64[D]')

print(dates)
# Out:
# ['2023-01-01' '2023-01-02' '2023-01-03' '2023-01-04' '2023-01-05'
#  '2023-01-06' '2023-01-07' '2023-01-08' '2023-01-09' '2023-01-10'
#  '2023-01-11' '2023-01-12' '2023-01-13' '2023-01-14' '2023-01-15'
#  '2023-01-16' '2023-01-17' '2023-01-18' '2023-01-19' '2023-01-20'
#  '2023-01-21' '2023-01-22' '2023-01-23' '2023-01-24' '2023-01-25'
#  '2023-01-26' '2023-01-27' '2023-01-28' '2023-01-29' '2023-01-30'
#  '2023-01-31']

# %% [markdown]
# ## Exercice 4

# %%
import pandas as pd

# Création d'un DataFrame contenant des nombres aléatoires
df = pd.DataFrame(np.random.randint(1, 100, size=(5, 4)), columns=["A", "B", "C", "D"])

print("DataFrame aléatoire :")
print(df)

# 1. Sélection conditionnelle des données
selection = df[df["A"] > 50]
print("\nLignes où la colonne A est supérieure à 50 :")
print(selection)

# 2. Fonctions d'agrégation
somme = df.sum()
moyenne = df.mean()

print("\nSomme par colonne :")
print(somme)

print("\nMoyenne par colonne :")
print(moyenne)
# Out:
# DataFrame aléatoire :
#     A   B   C   D
# 0  73  60  64  27
# 1  81  45  27  74
# 2  65  38  95  75
# 3  98  70  98  68
# 4  62   5  20   1
#
# Lignes où la colonne A est supérieure à 50 :
#     A   B   C   D
# 0  73  60  64  27
# 1  81  45  27  74
# 2  65  38  95  75
# 3  98  70  98  68
# 4  62   5  20   1
#
# Somme par colonne :
# A    379
# B    218
# C    304
# D    245
# dtype: int64
#
# Moyenne par colonne :
# A    75.8
# B    43.6
# C    60.8
# D    49.0
# dtype: float64

# %% [markdown]
# ## Exercice 5

# %%
import numpy as np
import matplotlib.pyplot as plt

image = np.array([
    [0, 50, 100, 150, 200],
    [50, 100, 150, 200, 255],
    [100, 150, 200, 255, 200],
    [150, 200, 255, 200, 150],
    [200, 255, 200, 150, 100]
])

plt.imshow(image, cmap='gray')
plt.title("Image 5x5 en niveaux de gris")
plt.colorbar()
plt.show()

# %% [markdown]
# ## Exercice 6

# %%
import numpy as np
from scipy import stats

# Productivity scores of employees before the training program
productivity_before = np.random.normal(loc=50, scale=10, size=30)

# Productivity scores of the same employees after the training program
productivity_after = productivity_before + np.random.normal(loc=5, scale=3, size=30)

# Your task is to formulate a hypothesis regarding the training program's effectiveness 
# and test it using basic statistical functions in NumPy.
test_statistic, p_value = stats.ttest_rel(
    productivity_after,
    productivity_before
)

print("Statistique t :", test_statistic)
print("p-value :", p_value)
# Out:
# Statistique t : 9.81560029331586
# p-value : 1.005030295768846e-10

# %% [markdown]
# ## Exercice 7

# %%
tableau1 = np.random.rand(3, 3)
tableau2 = np.random.rand(3, 3)

resultat = tableau1 > tableau2

print(resultat)
# Out:
# [[False False False]
#  [False  True False]
#  [ True  True False]]

# %% [markdown]
# ## Exercice 8

# %%
import numpy as np

# Génération des dates de l'année 2023
dates = np.arange('2023-01', '2024-01', dtype='datetime64[M]')

# Génération de données aléatoires (par exemple des ventes ou températures)
valeurs = np.random.randint(10, 100, size=12)

print("Dates :")
print(dates)

print("Valeurs :")
print(valeurs)

# Janvier à Mars
jan_mar = valeurs[0:3]
print("Janvier à Mars :")
print(jan_mar)

# Avril à Juin
avr_jun = valeurs[3:6]
print("Avril à Juin :")
print(avr_jun)

# Juillet à Septembre
jul_sep = valeurs[6:9]
print("Juillet à Septembre :")
print(jul_sep)

# Octobre à Décembre
oct_dec = valeurs[9:12]
print("Octobre à Décembre :")
print(oct_dec)

# %% [markdown]
# ## Exercice 9

# %%
import numpy as np
import pandas as pd

# Création d'un tableau NumPy
tableau = np.array([
    [10, 20, 30],
    [40, 50, 60],
    [70, 80, 90]
])

# Conversion en DataFrame
df = pd.DataFrame(
    tableau,
    columns=["A", "B", "C"]
)

print(df)
# Out:
#     A   B   C
# 0  10  20  30
# 1  40  50  60
# 2  70  80  90

# %% [markdown]
# ## Exercice 10

# %%
array = np.random.rand(50)
plt.plot(array)
plt.title("Graphique de l'array aléatoire")
plt.xlabel("index")
plt.ylabel("valeur")
plt.show()
