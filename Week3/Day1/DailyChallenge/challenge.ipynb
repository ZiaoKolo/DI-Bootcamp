# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


# 1. Préparation des données


# Liste des villes
villes = [
    "Abidjan", "Paris", "Londres", "New York", "Tokyo",
    "Moscou", "Caire", "Sydney", "Berlin", "Madrid"
]

# Liste des mois
mois = [
    "Jan", "Fev", "Mar", "Avr", "Mai", "Juin",
    "Juil", "Aout", "Sep", "Oct", "Nov", "Dec"
]

# Génération aléatoire des températures
temperatures = np.random.uniform(-5, 35, (10, 12))

# Création du DataFrame
df = pd.DataFrame(
    temperatures,
    index=villes,
    columns=mois
)

print("Données de température")
print(df)

# 2. Analyse des données


# Température moyenne annuelle par ville
moyennes = df.mean(axis=1)

print("Température moyenne annuelle :")
print(moyennes)

# Ville la plus chaude
ville_plus_chaude = moyennes.idxmax()

# Ville la plus froide
ville_plus_froide = moyennes.idxmin()

print("Ville la plus chaude :", ville_plus_chaude)
print("Ville la plus froide :", ville_plus_froide)


# 3. Visualisation


plt.figure(figsize=(10, 6))

for ville in villes:
    plt.plot(mois, df.loc[ville], marker='o', label=ville)

plt.title("Evolution des températures mensuelles")
plt.xlabel("Mois")
plt.ylabel("Température (°C)")
plt.legend()
plt.grid(True)

plt.show()
# Out:
# === Données de température ===
#                 Jan        Fev        Mar        Avr        Mai       Juin  \
# Abidjan   28.988021   1.661351  30.078145   8.717152  -2.203536  31.198433
# Paris      0.425009  -0.030261  -3.836861  -0.634928  21.721416  10.067849
# Londres   24.165359   4.573047  30.861843   8.428542  33.700031  29.337640
# New York   5.546894   5.591267  26.562269   2.501273  33.886093  28.605475
# Tokyo      5.216152   4.582653  34.376338  15.146959   3.770669   7.355030
# Moscou    33.367781  16.815670   1.144889  17.965550  27.357899  -2.612412
# Caire     11.018541   6.511998   6.836773  28.276595   0.931609  -4.885763
# Sydney    26.517304  23.565141  -3.752902  11.539560   9.335667   1.147537
# Berlin    19.961230  17.992396  21.199657  25.221999  26.055443   7.026683
# Madrid     7.089624  12.785510  21.906613  26.823083  21.510655  34.723548
#
#                Juil       Aout        Sep        Oct        Nov        Dec
# ...
